# %%
import pandas as pd
import numpy as np
from scipy import linalg
import matplotlib.pyplot as plt

# %%
points1 = np.array([1,15])
points2 = np.array([1,8,15])
points3 = np.array([1,4,10,15])
points4 = np.linspace(1,15,num=50)

# %% [markdown]
# f(x) = sin(x / 5) * exp(x / 10) + 5 * exp(-x / 2)

# %%
def fx(x):
    return np.sin(x/5)*np.exp(x/10) + 5*np.exp(-x/2)

# %%
# %matplotlib inline

# %%
plt.plot(points4, fx(points4))

# %% [markdown]
# # 1. Многочлен первой степени

# %%
y = fx(points1)
y
# Out:
# array([3.25221687, 0.63522142])

# %%
#scipy.linalg.solve

# %%
A = points1.reshape(len(y),1)
A
# Out:
# array([[ 1],
#        [15]])

# %%
A = np.hstack((A, np.ones((len(y),1))))

# %%
x = sc.linalg.solve(A,y)
x
# Out:
# array([-0.18692825,  3.43914511])

# %%
# %matplotlib inline
plt.plot(points1,y)
plt.plot(points4, fx(points4))

# %%
y2 = fx(points2)

# %%
a = points2.reshape(len(y2),1)
b = np.ones((len(y2),1))
A2 = np.hstack((a*a , a, b))

# %%
x2 = sc.linalg.solve(A2,y2)

# %%
def fx2(x, x2):
    return x2[0]*x*x + x2[1]*x + x2[2]

# %%
y2c = fx2(points4,x2)

# %%
plt.plot(y2c,points4)

# %%
y3 = fx(points3)

a = points3.reshape(len(y3),1)
b = np.ones((len(y3),1))
A3 = np.hstack((a*a*a, a*a , a, b))

x3 = sc.linalg.solve(A3,y3)

def fx3(x, x3):
    return x3[0]*x*x*x + x3[1]*x*x + x3[2]*x+x3[3]

y3c = fx3(points4,x3)

# %%
x3
# Out:
# array([-0.00823565,  0.19333685, -1.29552587,  4.36264154])
